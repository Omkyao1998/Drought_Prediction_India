# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
latur_dist = pd.read_csv("datasets/latur_dist.csv", sep=',', skiprows=25)

osmanabad_dist = pd.read_csv("datasets/osmanabad_dist.csv", sep=',', skiprows=25)

# %% [markdown]
# ### Features Description
#
# |PARAMETERS      |DESCRIPTION                                       |
# |--              |--                                                |
# |PS              |    MERRA-2 Surface Pressure (kPa)                |
# |TS              |    MERRA-2 Earth Skin Temperature (C)            |
# |T2M             |    MERRA-2 Temperature at 2 Meters (C)           |
# |QV2M            |    MERRA-2 Specific Humidity at 2 Meters (g/kg)  |
# |RH2M            |    MERRA-2 Relative Humidity at 2 Meters (%)     |
# |WD2M            |    MERRA-2 Wind Direction at 2 Meters (Degrees)  |
# |WS2M            |    MERRA-2 Wind Speed at 2 Meters (m/s)          |
# |T2MDEW          |    MERRA-2 Dew/Frost Point at 2 Meters (C)       |
# |T2MWET          |    MERRA-2 Wet Bulb Temperature at 2 Meters (C)  |
# |GWETTOP         |    MERRA-2 Surface Soil Wetness (1)              |
# |GWETPROF        |    MERRA-2 Profile Soil Moisture (1)             |
# |GWETROOT        |    MERRA-2 Root Zone Soil Wetness (1)            |
# |WS2M_MAX        |    MERRA-2 Wind Speed at 2 Meters Maximum (m/s)  |
# |WS2M_MIN        |    MERRA-2 Wind Speed at 2 Meters Minimum (m/s)  |
# |WS2M_RANGE      |    MERRA-2 Wind Speed at 2 Meters Range (m/s)    |
# |PRECTOTCORR     |    MERRA-2 Precipitation Corrected (mm/day)      |
# |PRECTOTCORR_SUM |    MERRA-2 Precipitation Corrected Sum (mm)      |

# %%
latur_dist["PARAMETER"].unique()
# Out:
# array(['PS', 'TS', 'T2M', 'QV2M', 'RH2M', 'WD2M', 'WS2M', 'T2MDEW',
#        'T2MWET', 'GWETTOP', 'GWETPROF', 'GWETROOT', 'WS2M_MAX',
#        'WS2M_MIN', 'WS2M_RANGE', 'PRECTOTCORR', 'PRECTOTCORR_SUM'],
#       dtype=object)

# %%
latur_dist.query("""YEAR=='1981'""")
# Out:
#            PARAMETER  YEAR    JAN     FEB     MAR     APR     MAY     JUN  \
# 0                 PS  1981  95.18   95.02   94.89   94.58   94.35   94.12
# 41                TS  1981  21.40   26.57   29.42   35.19   35.55   30.55
# 82               T2M  1981  20.40   25.28   27.55   32.68   32.96   29.08
# 123             QV2M  1981   7.08    4.64    7.81    6.04   11.17   15.87
# 164             RH2M  1981  49.19   23.69   34.62   20.06   36.56   62.75
# 205             WD2M  1981  70.56  106.12  115.00  330.06  312.94  267.94
# 246             WS2M  1981   1.95    1.80    2.06    2.59    3.39    4.73
# 287           T2MDEW  1981   7.67    1.20    7.65    4.52   14.37   20.18
# 328           T2MWET  1981  14.03   13.24   17.59   18.60   23.66   24.63
# 369          GWETTOP  1981   0.42    0.26    0.34    0.20    0.39    0.64
# 410         GWETPROF  1981   0.61    0.60    0.61    0.60    0.61    0.66
# 451         GWETROOT  1981   0.61    0.59    0.60    0.59    0.60    0.66
# ...

# %%
latur_dist.columns
# Out:
# Index(['PARAMETER', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANN'],
#       dtype='object')

# %%
latur_dist.shape, osmanabad_dist.shape
# Out:
# ((697, 15), (697, 15))

# %%
latur_dist.groupby(['YEAR', 'PARAMETER'])[['JAN', 'FEB']].sum().reset_index().melt(id_vars=['PARAMETER'], value_vars=['JAN', 'FEB'])
# Out:
#             PARAMETER variable  value
# 0            GWETPROF      JAN   0.61
# 1            GWETROOT      JAN   0.61
# 2             GWETTOP      JAN   0.42
# 3         PRECTOTCORR      JAN   0.80
# 4     PRECTOTCORR_SUM      JAN  21.09
# ...               ...      ...    ...
# 1389             WD2M      FEB  91.50
# 1390             WS2M      FEB   1.98
# 1391         WS2M_MAX      FEB   4.75
# 1392         WS2M_MIN      FEB   0.15
# 1393       WS2M_RANGE      FEB   4.60
#
# [1394 rows x 3 columns]

# %%
latur_dist.set_index(['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANN']).T
# Out:
# YEAR         1981    1982    1983    1984    1985    1986    1987    1988  \
# JAN         95.18   95.13   95.21   94.92   95.01   95.09   95.21   95.11
# FEB         95.02   94.92   94.94   94.90   94.62   94.90   95.11   94.89
# MAR         94.89   94.78   94.83   94.80   94.73   94.73   94.83   94.69
# APR         94.58   94.62   94.61   94.47   94.44   94.51   94.64   94.61
# MAY         94.35   94.56   94.41   94.21   94.19   94.33   94.67   94.21
# JUN        94.12   94.19   94.17   94.06   94.16   94.12   94.18   94.20
# JUL        94.19   94.18   94.17   94.13   94.28   94.26   94.38   94.15
# AUG        94.22   94.25   94.20   94.26   94.25   94.30   94.25   94.26
# SEP        94.46   94.59   94.36   94.56   94.52   94.59   94.60   94.31
# OCT        94.88   94.96   94.73   94.80   94.75   94.87   94.84   94.83
# NOV         95.05   95.04   95.24   95.15   95.06   95.01   94.95   95.18
# DEC         95.32   95.22   95.17   94.97   95.13   95.19   95.29   95.28
# ...

# %%
latur_dist_gb = latur_dist.groupby(["YEAR", "PARAMETER"])[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL','AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANN']].sum().reset_index()
latur_dist_gb['district'] = 'Latur'

osmanabad_dist_gb = osmanabad_dist.groupby(["YEAR", "PARAMETER"])[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL','AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANN']].sum().reset_index()
osmanabad_dist_gb['district'] = 'Osmanabad'

# %%
latur_dist_gb.head()
# Out:
#    YEAR        PARAMETER    JAN   FEB    MAR   APR    MAY     JUN     JUL  \
# 0  1981         GWETPROF   0.61  0.60   0.61  0.60   0.61    0.66    0.73
# 1  1981         GWETROOT   0.61  0.59   0.60  0.59   0.60    0.66    0.73
# 2  1981          GWETTOP   0.42  0.26   0.34  0.20   0.39    0.64    0.76
# 3  1981      PRECTOTCORR   0.80  0.04   0.88  0.22   1.44    6.94    4.51
# 4  1981  PRECTOTCORR_SUM  21.09  0.00  21.09  0.00  31.64  205.66  147.66
#
#       AUG     SEP     OCT   NOV   DEC      ANN district
# 0    0.79    0.88    0.93  0.82  0.71     0.71    Latur
# 1    0.78    0.88    0.93  0.80  0.70     0.71    Latur
# 2    0.81    0.91    0.91  0.82  0.71     0.60    Latur
# 3    6.26   15.57    3.90  0.47  0.30     3.45    Latur
# 4  184.57  458.79  110.74  5.27  5.27  1191.80    Latur

# %%
osmanabad_dist_gb.head()
# Out:
#    YEAR        PARAMETER    JAN   FEB    MAR   APR    MAY     JUN    JUL  \
# 0  1981         GWETPROF   0.61  0.60   0.60  0.60   0.61    0.66   0.69
# 1  1981         GWETROOT   0.60  0.59   0.60  0.59   0.60    0.66   0.69
# 2  1981          GWETTOP   0.38  0.25   0.31  0.20   0.41    0.65   0.70
# 3  1981      PRECTOTCORR   0.74  0.01   0.80  0.20   1.54    6.02   2.50
# 4  1981  PRECTOTCORR_SUM  21.09  0.00  21.09  0.00  42.19  168.75  58.01
#
#       AUG     SEP     OCT    NOV   DEC      ANN   district
# 0    0.72    0.83    0.91   0.80  0.70     0.70  Osmanabad
# 1    0.72    0.83    0.90   0.80  0.70     0.69  Osmanabad
# 2    0.74    0.87    0.90   0.80  0.70     0.58  Osmanabad
# 3    4.28   17.50    4.04   0.56  0.13     3.19  Osmanabad
# 4  110.74  511.52  110.74  10.55  0.00  1054.69  Osmanabad

# %%
all_dist = pd.concat([latur_dist_gb, osmanabad_dist_gb], ignore_index=True)

# %%
all_dist.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  1394.000000  1394.000000  1394.000000  1394.000000  1394.000000
# mean   2001.000000    19.756650    20.876306    22.115796    28.757633
# std      11.836406    32.544614    42.480092    45.941140    63.187412
# min    1981.000000     0.000000    -5.180000    -2.930000     0.000000
# 25%    1991.000000     0.600000     0.590000     0.590000     0.600000
# 50%    2001.000000     5.100000     5.200000     5.580000     6.485000
# 75%    2011.000000    22.320000    24.887500    26.785000    30.150000
# max    2021.000000   170.500000   352.940000   359.440000   359.880000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  1394.000000  1394.000000  1394.000000  1394.000000  1394.000000
# mean     35.359577    40.985423    42.688537    42.868587    45.166155
# std      71.989032    68.012112    70.915106    71.472168    79.307899
# ...

# %%
latur_dist.columns
# Out:
# Index(['PARAMETER', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANN'],
#       dtype='object')

# %% [markdown]
# ### Univariate Analysis of Attributes

# %%
for col in all_dist["PARAMETER"].unique():
    # plt.figure(figsize=(20,7))
    plt.title(col)
    param_data = all_dist[all_dist["PARAMETER"]==col][["YEAR", "PARAMETER","ANN", "district"]]
    sns.kdeplot(data=param_data, x="ANN", shade=True, hue="district")
    plt.show()

# %% [markdown]
# ### Comparitive Analysis of Attributes between 2 Districts

# %%
for col in all_dist["PARAMETER"].unique():
    plt.figure(figsize=(20,7))
    plt.title(col)
    param_data = all_dist[all_dist["PARAMETER"]==col][["YEAR", "PARAMETER","ANN", "district"]]
    sns.lineplot(data=param_data, x="YEAR", y="ANN", hue="district", marker="o")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## Calculate SPI
#
# - The Standardized Precipitation Index (SPI) is a widely accepted index for the quantification of drought.
# - The SPI specifically addresses the intensity of meteorological drought, or precipitation deficit.
# - The shortage of precipitation is a fundamental, intuitive metric for drought—perhaps the most basic description possible.
# - The SPI can compute drought intensity over any desired interval, e.g., one month, five months or 200 days.
# - For example, the precipitation totals for one, three, six, 12, 18, 24, 36, 48, and 60 month durations are routinely used by researchers to compute the SPI for the same respective intervals.
# - The SPI can accomplish the simultaneous assessment of drought because the observed precipitation during each time period is considered a statistical sample from a larger parent population.
#
# > SPI = (P - MEAN(P)) /  SD(P)
#
# Where,
# P = precipitation
#
# MEAN(P) = mean precipitation
#
# SD(P) = standard deviation of precipitation
#
# - The dimensionless SPI values are typically associated with the drought descriptions of “dry”, “moderately dry”, or “extremely dry”, as well as other labels for near-normal conditions or precipitation excesses.

# %%
all_dist1 = all_dist.set_index(['district', "YEAR", "PARAMETER"]).reset_index().rename(columns={'level_3':'MONTH', 0:'VALUE'})
all_dist1
# Out:
#        district  YEAR        PARAMETER     JAN    FEB     MAR    APR     MAY  \
# 0         Latur  1981         GWETPROF    0.61   0.60    0.61   0.60    0.61
# 1         Latur  1981         GWETROOT    0.61   0.59    0.60   0.59    0.60
# 2         Latur  1981          GWETTOP    0.42   0.26    0.34   0.20    0.39
# 3         Latur  1981      PRECTOTCORR    0.80   0.04    0.88   0.22    1.44
# 4         Latur  1981  PRECTOTCORR_SUM   21.09   0.00   21.09   0.00   31.64
# ...         ...   ...              ...     ...    ...     ...    ...     ...
# 1389  Osmanabad  2021             WD2M  118.00  97.44  120.31  39.50  264.00
# 1390  Osmanabad  2021             WS2M    1.70   2.05    2.19   1.83    3.19
# 1391  Osmanabad  2021         WS2M_MAX    4.42   5.38    6.34   5.31    8.79
# 1392  Osmanabad  2021         WS2M_MIN    0.04   0.14    0.05   0.05    0.09
# 1393  Osmanabad  2021       WS2M_RANGE    4.38   5.24    6.30   5.26    8.70
#
# ...

# %%
all_dist.columns
# Out:
# Index(['YEAR', 'PARAMETER', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANN', 'district'],
#       dtype='object')

# %%
all_dist.melt(id_vars=['district', 'YEAR'], value_vars=['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANN'])
# Out:
#         district  YEAR variable   value
# 0          Latur  1981      JAN    0.61
# 1          Latur  1981      JAN    0.61
# 2          Latur  1981      JAN    0.42
# 3          Latur  1981      JAN    0.80
# 4          Latur  1981      JAN   21.09
# ...          ...   ...      ...     ...
# 18117  Osmanabad  2021      ANN  276.00
# 18118  Osmanabad  2021      ANN    2.58
# 18119  Osmanabad  2021      ANN    8.84
# 18120  Osmanabad  2021      ANN    0.04
# 18121  Osmanabad  2021      ANN    8.80
#
# [18122 rows x 4 columns]

# %%
all_dist.groupby(['PARAMETER', 'YEAR', 'district'])[['JAN', 'FEB']].sum()
# Out:
#                             JAN   FEB
# PARAMETER  YEAR district
# GWETPROF   1981 Latur      0.61  0.60
#                 Osmanabad  0.61  0.60
#            1982 Latur      0.65  0.62
#                 Osmanabad  0.64  0.61
#            1983 Latur      0.60  0.60
# ...                         ...   ...
# WS2M_RANGE 2019 Osmanabad  5.55  5.17
#            2020 Latur      4.97  5.50
#                 Osmanabad  5.05  5.87
#            2021 Latur      4.29  4.60
#                 Osmanabad  4.38  5.24
#
# [1394 rows x 2 columns]

# %%
# all_dist.pivot_table(columns=['PARAMETER'],
#                      values=['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 
#                              'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANN'])
