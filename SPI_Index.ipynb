# %%
# libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import Dense, Activation, LSTM
from math import sqrt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ENSO_data = pd.read_csv("/content/drive/MyDrive/MCM Practicum/ENSO.csv")

# %%
ENSO_data.describe()
# Out:
#               Year         PNA         SOI
# count   859.000000  859.000000  859.000000
# mean   1986.293364   -0.094820    0.145402
# std      20.677287    1.030522    0.938163
# min    1951.000000   -3.190000   -3.600000
# 25%    1968.000000   -0.760000   -0.400000
# 50%    1986.000000   -0.070000    0.200000
# 75%    2004.000000    0.605000    0.800000
# max    2022.000000    2.870000    2.900000

# %% [markdown]
# # Enso Indicator
#
# > If SOI > 0.5 -> Warm -> El Nino
#
# > If SOI < 0.5 -> Cool -> La Nina

# %%
ENSO_data.head()
# Out:
#          Date  Year Month    Season   ONI NINO 1+2 SST NINO 1+2 SST Anomalies  \
# 0  01-01-1951  1951   JAN  DJF 1951  -0.8          NAN                    NAN
# 1  01-02-1951  1951   FEB  JFM 1951  -0.5          NAN                    NAN
# 2  01-03-1951  1951   MAR  FMA 1951  -0.2          NAN                    NAN
# 3  01-04-1951  1951   APR  MAM 1951   0.2          NAN                    NAN
# 4  01-05-1951  1951   MAY  AMJ 1951   0.4          NAN                    NAN
#
#   NINO 3 SST NINO 3 SST Anomalies NINO 3.4 SST NINO 3.4 SST Anomalies  \
# 0        NAN                  NAN          NAN                    NAN
# 1        NAN                  NAN          NAN                    NAN
# 2        NAN                  NAN          NAN                    NAN
# 3        NAN                  NAN          NAN                    NAN
# 4        NAN                  NAN          NAN                    NAN
#
#   NINO 4 SST NINO 4 SST Anomalies  OLR    TNI   PNA Precipitation (mm/day)  \
# 0        NAN                  NAN  NAN  1.315 -1.18                    NAN
# 1        NAN                  NAN  NAN  1.461 -2.11                    NAN
# 2        NAN                  NAN  NAN   1.59 -1.09                    NAN
# 3        NAN                  NAN  NAN  1.457  0.47                    NAN
# 4        NAN                  NAN  NAN  1.615  1.19                    NAN
#
#    SOI  Effects
# 0  1.5  El Nino
# 1  0.9  El Nino
# 2 -0.1  La Nina
# 3 -0.3  La Nina
# 4 -0.7  La Nina

# %%
ENSO_data['Date'] = pd.to_datetime(ENSO_data['Date'])

# %%
start_date = pd.to_datetime('01-01-1982')
end_date = pd.to_datetime('01-12-2021')

data = ENSO_data[(ENSO_data['Date']>= start_date) & (ENSO_data['Date']<= end_date)]
data.head()
# Out:
#           Date  Year Month    Season   ONI NINO 1+2 SST  \
# 372 1982-01-01  1982   JAN  DJF 1982  -0.1        24.28
# 373 1982-01-02  1982   FEB  JFM 1982   0.1        25.38
# 374 1982-01-03  1982   MAR  FMA 1982   0.2        25.22
# 375 1982-01-04  1982   APR  MAM 1982   0.5        24.57
# 376 1982-01-05  1982   MAY  AMJ 1982   0.7           24
#
#     NINO 1+2 SST Anomalies NINO 3 SST NINO 3 SST Anomalies NINO 3.4 SST  \
# 372                  -0.24      25.84                 0.17        26.65
# 373                  -0.72      26.26                -0.11        26.54
# 374                  -1.38      26.92                -0.25        27.09
# 375                  -1.16      27.52                -0.05        27.83
# 376                  -0.62       27.7                 0.49        28.37
#
#     NINO 3.4 SST Anomalies NINO 4 SST NINO 4 SST Anomalies   OLR     TNI  \
# 372                   0.08      28.01                -0.21   0.9  -1.067
# 373                   -0.2      27.99                -0.11   0.1  -1.466
# 374                  -0.14      28.18                -0.05  -0.6  -1.922
# 375                   0.02      28.61                  0.1     0  -2.359
# 376                   0.49      29.19                  0.4   0.4  -2.364
#
#       PNA Precipitation (mm/day)  SOI  Effects   Effect
# 372 -1.75                   5.66  1.2  El Nino  El-Nino
# 373 -1.20                    5.5  0.3  La Nina  La-Nina
# 374 -1.66                   0.44  0.6  El Nino  El-Nino
# 375 -2.08                   0.28  0.1  La Nina  La-Nina
# 376 -0.53                   2.51 -0.3  La Nina  La-Nina

# %%
data = data.drop(['Effect'], axis=1)

# %%
data.head()
# Out:
#           Date  Year Month    Season   ONI NINO 1+2 SST  \
# 372 1982-01-01  1982   JAN  DJF 1982  -0.1        24.28
# 373 1982-01-02  1982   FEB  JFM 1982   0.1        25.38
# 374 1982-01-03  1982   MAR  FMA 1982   0.2        25.22
# 375 1982-01-04  1982   APR  MAM 1982   0.5        24.57
# 376 1982-01-05  1982   MAY  AMJ 1982   0.7           24
#
#     NINO 1+2 SST Anomalies NINO 3 SST NINO 3 SST Anomalies NINO 3.4 SST  \
# 372                  -0.24      25.84                 0.17        26.65
# 373                  -0.72      26.26                -0.11        26.54
# 374                  -1.38      26.92                -0.25        27.09
# 375                  -1.16      27.52                -0.05        27.83
# 376                  -0.62       27.7                 0.49        28.37
#
#     NINO 3.4 SST Anomalies NINO 4 SST NINO 4 SST Anomalies   OLR     TNI  \
# 372                   0.08      28.01                -0.21   0.9  -1.067
# 373                   -0.2      27.99                -0.11   0.1  -1.466
# 374                  -0.14      28.18                -0.05  -0.6  -1.922
# 375                   0.02      28.61                  0.1     0  -2.359
# 376                   0.49      29.19                  0.4   0.4  -2.364
#
#       PNA Precipitation (mm/day)  SOI  Effects
# 372 -1.75                   5.66  1.2  El Nino
# 373 -1.20                    5.5  0.3  La Nina
# 374 -1.66                   0.44  0.6  El Nino
# 375 -2.08                   0.28  0.1  La Nina
# 376 -0.53                   2.51 -0.3  La Nina

# %% [markdown]
# ###Calculating SPI

# %%
d_data = pd.read_csv('/content/drive/MyDrive/MCM Practicum/Drought_1.csv')

# %%
d_data.head()
# Out:
#    YEAR  DOY    T2M  T2MDEW  T2MWET     TS  T2M_RANGE  T2M_MAX  T2M_MIN  \
# 0  2000    1  20.13    1.11   10.62  21.09      18.48    30.14    11.67
# 1  2000    2  20.03    0.70   10.37  20.99      17.95    29.82    11.87
# 2  2000    3  19.96   -0.36    9.80  20.97      17.87    29.87    12.00
# 3  2000    4  19.80   -2.26    8.76  20.80      18.05    29.90    11.85
# 4  2000    5  19.30   -2.79    8.25  20.48      19.01    29.58    10.58
#
#    ALLSKY_SFC_LW_DWN  QV2M   RH2M  PRECTOTCORR  GWETTOP  GWETROOT  GWETPROF
# 0              335.5  4.39  31.56          0.0     0.23      0.59       0.6
# 1              329.9  4.21  30.69          0.0     0.23      0.59       0.6
# 2              329.9  3.91  28.44          0.0     0.23      0.59       0.6
# 3              326.3  3.42  25.25          0.0     0.23      0.59       0.6
# 4              322.9  3.23  25.06          0.0     0.22      0.59       0.6

# %%
d_data['Date'] = pd.to_datetime(d_data['YEAR'], format='%Y') + pd.to_timedelta(d_data['DOY'] - 1, unit='D')

# %%
# !pip install standard-precip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting standard-precip
#   Downloading standard_precip-1.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from standard-precip) (1.22.4)
# Requirement already satisfied: matplotlib>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from standard-precip) (3.7.1)
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from standard-precip) (1.10.1)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from standard-precip) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->standard-precip) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->standard-precip) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->standard-precip) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->standard-precip) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->standard-precip) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->standard-precip) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->standard-precip) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->standard-precip) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->standard-precip) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.2->standard-precip) (1.16.0)
# Installing collected packages: standard-precip
# Successfully installed standard-precip-1.0

# %%
from standard_precip.spi import SPI
from standard_precip.utils import plot_index

# %%
spi = SPI()
new_spi = SPI()

# %%
d_data
# Out:
#       YEAR  DOY    T2M  T2MDEW  T2MWET     TS  T2M_RANGE  T2M_MAX  T2M_MIN  \
# 0     2000    1  20.13    1.11   10.62  21.09      18.48    30.14    11.67
# 1     2000    2  20.03    0.70   10.37  20.99      17.95    29.82    11.87
# 2     2000    3  19.96   -0.36    9.80  20.97      17.87    29.87    12.00
# 3     2000    4  19.80   -2.26    8.76  20.80      18.05    29.90    11.85
# 4     2000    5  19.30   -2.79    8.25  20.48      19.01    29.58    10.58
# ...    ...  ...    ...     ...     ...    ...        ...      ...      ...
# 7667  2020  363  19.61   12.14   15.87  19.18      14.47    27.26    12.79
# 7668  2020  364  19.08   12.08   15.58  19.12      15.62    27.71    12.08
# 7669  2020  365  19.12   12.74   15.93  19.11      15.30    27.55    12.25
# 7670  2020  366  18.86   12.46   15.65  18.96      13.95    26.92    12.97
# 7671  2021    1  19.62   13.15   16.39  19.75      13.60    27.26    13.66
#
#       ALLSKY_SFC_LW_DWN   QV2M   RH2M  PRECTOTCORR  GWETTOP  GWETROOT  \
# 0                335.50   4.39  31.56         0.00     0.23      0.59
# 1                329.90   4.21  30.69         0.00     0.23      0.59
# 2                329.90   3.91  28.44         0.00     0.23      0.59
# 3                326.30   3.42  25.25         0.00     0.23      0.59
# 4                322.90   3.23  25.06         0.00     0.22      0.59
# ...                 ...    ...    ...          ...      ...       ...
# 7667             352.03   9.34  64.50         0.00     0.66      0.66
# 7668             349.76   9.34  67.00         0.00     0.65      0.66
# 7669             352.66   9.70  69.75         0.00     0.65      0.66
# 7670             364.25   9.52  69.44         0.00     0.65      0.66
# 7671             382.48  10.07  68.00         0.01     0.64      0.66
#
#       GWETPROF       Date
# 0         0.60 2000-01-01
# 1         0.60 2000-01-02
# 2         0.60 2000-01-03
# 3         0.60 2000-01-04
# 4         0.60 2000-01-05
# ...        ...        ...
# 7667      0.68 2020-12-28
# 7668      0.67 2020-12-29
# 7669      0.67 2020-12-30
# 7670      0.67 2020-12-31
# 7671      0.67 2021-01-01
#
# [7672 rows x 17 columns]

# %%
d_data
# Out:
#       YEAR  DOY    T2M  T2MDEW  T2MWET     TS  T2M_RANGE  T2M_MAX  T2M_MIN  \
# 0     2000    1  20.13    1.11   10.62  21.09      18.48    30.14    11.67
# 1     2000    2  20.03    0.70   10.37  20.99      17.95    29.82    11.87
# 2     2000    3  19.96   -0.36    9.80  20.97      17.87    29.87    12.00
# 3     2000    4  19.80   -2.26    8.76  20.80      18.05    29.90    11.85
# 4     2000    5  19.30   -2.79    8.25  20.48      19.01    29.58    10.58
# ...    ...  ...    ...     ...     ...    ...        ...      ...      ...
# 7667  2020  363  19.61   12.14   15.87  19.18      14.47    27.26    12.79
# 7668  2020  364  19.08   12.08   15.58  19.12      15.62    27.71    12.08
# 7669  2020  365  19.12   12.74   15.93  19.11      15.30    27.55    12.25
# 7670  2020  366  18.86   12.46   15.65  18.96      13.95    26.92    12.97
# 7671  2021    1  19.62   13.15   16.39  19.75      13.60    27.26    13.66
#
#       ALLSKY_SFC_LW_DWN   QV2M   RH2M  PRECTOTCORR  GWETTOP  GWETROOT  \
# 0                335.50   4.39  31.56         0.00     0.23      0.59
# 1                329.90   4.21  30.69         0.00     0.23      0.59
# 2                329.90   3.91  28.44         0.00     0.23      0.59
# 3                326.30   3.42  25.25         0.00     0.23      0.59
# 4                322.90   3.23  25.06         0.00     0.22      0.59
# ...                 ...    ...    ...          ...      ...       ...
# 7667             352.03   9.34  64.50         0.00     0.66      0.66
# 7668             349.76   9.34  67.00         0.00     0.65      0.66
# 7669             352.66   9.70  69.75         0.00     0.65      0.66
# 7670             364.25   9.52  69.44         0.00     0.65      0.66
# 7671             382.48  10.07  68.00         0.01     0.64      0.66
#
#       GWETPROF       Date
# 0         0.60 2000-01-01
# 1         0.60 2000-01-02
# 2         0.60 2000-01-03
# 3         0.60 2000-01-04
# 4         0.60 2000-01-05
# ...        ...        ...
# 7667      0.68 2020-12-28
# 7668      0.67 2020-12-29
# 7669      0.67 2020-12-30
# 7670      0.67 2020-12-31
# 7671      0.67 2021-01-01
#
# [7672 rows x 17 columns]

# %%
df_spi = new_spi.calculate(
    d_data,
    'Date',
    'PRECTOTCORR',
    freq="M",
    scale=1,
    fit_type="lmom",
    dist_type="gam"
)

# %%
df_spi
# Out:
#            Date  PRECTOTCORR  PRECTOTCORR_calculated_index
# 0    2000-01-01         0.00                      1.292110
# 1    2000-01-02         0.00                      1.292110
# 2    2000-01-03         0.00                      1.292110
# 3    2000-01-04         0.00                      1.292110
# 4    2000-01-05         0.00                      1.292110
# ...         ...          ...                           ...
# 7667 2020-12-28         0.00                      1.482344
# 7668 2020-12-29         0.00                      1.482344
# 7669 2020-12-30         0.00                      1.482344
# 7670 2020-12-31         0.00                      1.482344
# 7671 2021-01-01         0.01                      1.490562
#
# [7672 rows x 3 columns]

# %%
df_spi['PRECTOTCORR_calculated_index']
# Out:
# 0       1.292110
# 1       1.292110
# 2       1.292110
# 3       1.292110
# 4       1.292110
#           ...
# 7667    1.482344
# 7668    1.482344
# 7669    1.482344
# 7670    1.482344
# 7671    1.490562
# Name: PRECTOTCORR_calculated_index, Length: 7672, dtype: float64

# %%
d_data['SPI_Index'] = df_spi['PRECTOTCORR_calculated_index']

# %%
d_data
# Out:
#       YEAR  DOY    T2M  T2MDEW  T2MWET     TS  T2M_RANGE  T2M_MAX  T2M_MIN  \
# 0     2000    1  20.13    1.11   10.62  21.09      18.48    30.14    11.67
# 1     2000    2  20.03    0.70   10.37  20.99      17.95    29.82    11.87
# 2     2000    3  19.96   -0.36    9.80  20.97      17.87    29.87    12.00
# 3     2000    4  19.80   -2.26    8.76  20.80      18.05    29.90    11.85
# 4     2000    5  19.30   -2.79    8.25  20.48      19.01    29.58    10.58
# ...    ...  ...    ...     ...     ...    ...        ...      ...      ...
# 7667  2020  363  19.61   12.14   15.87  19.18      14.47    27.26    12.79
# 7668  2020  364  19.08   12.08   15.58  19.12      15.62    27.71    12.08
# 7669  2020  365  19.12   12.74   15.93  19.11      15.30    27.55    12.25
# 7670  2020  366  18.86   12.46   15.65  18.96      13.95    26.92    12.97
# 7671  2021    1  19.62   13.15   16.39  19.75      13.60    27.26    13.66
#
#       ALLSKY_SFC_LW_DWN   QV2M   RH2M  PRECTOTCORR  GWETTOP  GWETROOT  \
# 0                335.50   4.39  31.56         0.00     0.23      0.59
# 1                329.90   4.21  30.69         0.00     0.23      0.59
# 2                329.90   3.91  28.44         0.00     0.23      0.59
# 3                326.30   3.42  25.25         0.00     0.23      0.59
# 4                322.90   3.23  25.06         0.00     0.22      0.59
# ...                 ...    ...    ...          ...      ...       ...
# 7667             352.03   9.34  64.50         0.00     0.66      0.66
# 7668             349.76   9.34  67.00         0.00     0.65      0.66
# 7669             352.66   9.70  69.75         0.00     0.65      0.66
# 7670             364.25   9.52  69.44         0.00     0.65      0.66
# 7671             382.48  10.07  68.00         0.01     0.64      0.66
#
#       GWETPROF       Date  SPI_Index
# 0         0.60 2000-01-01   1.292110
# 1         0.60 2000-01-02   1.292110
# 2         0.60 2000-01-03   1.292110
# 3         0.60 2000-01-04   1.292110
# 4         0.60 2000-01-05   1.292110
# ...        ...        ...        ...
# 7667      0.68 2020-12-28   1.482344
# 7668      0.67 2020-12-29   1.482344
# 7669      0.67 2020-12-30   1.482344
# 7670      0.67 2020-12-31   1.482344
# 7671      0.67 2021-01-01   1.490562
#
# [7672 rows x 18 columns]

# %%
#!pip install spei

# %%
#import spei as si

# %%
#import scipy.stats as scs
#spei = si.spei(d_data['PRECTOTCORR'])
